# %% [markdown]
# # =============================================================================
# # FACIAL EMOTION RECOGNITION - EXPERIMENT TEMPLATE
# # =============================================================================
# #
# # Universal template for running experiments with different configurations
# # Change parameters in Cell 1 to run different experiments
# #
# # Author: Pavlo Borysov
# # Date: 12/10/2025
# # =============================================================================

# %%
# custom loss function
import tensorflow as tf
def sparse_focal_loss(gamma=2.0, alpha=None, eps=1e-7):
    """
    Focal loss for sparse labels with softmax probabilities.
    alpha:
      - None -> no class weighting
      - list/tuple/np.array of shape [num_classes]
      - tf.Tensor same shape
    """
    alpha = None if alpha is None else tf.convert_to_tensor(alpha, dtype=tf.float32)

    def loss_fn(y_true, y_pred):
        # y_true: (batch,), ints; y_pred: (batch, num_classes), softmax probs
        y_true = tf.cast(y_true, tf.int32)
        num_classes = tf.shape(y_pred)[-1]
        y_true_oh = tf.one_hot(y_true, depth=num_classes, dtype=tf.float32)

        # pt = prob. of the true class
        pt = tf.reduce_sum(y_true_oh * tf.clip_by_value(y_pred, eps, 1.0), axis=-1)

        # alpha weighting per class (if provided)
        if alpha is not None:
            # gather alpha for the true class
            alpha_t = tf.reduce_sum(y_true_oh * alpha, axis=-1)
        else:
            alpha_t = 1.0

        focal = - alpha_t * tf.pow(1.0 - pt, gamma) * tf.math.log(pt)
        return tf.reduce_mean(focal)

    return loss_fn
# Out:
# 2025-10-12 21:56:19.174966: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-10-12 21:56:19.203453: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-10-12 21:56:19.203499: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-10-12 21:56:19.204429: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-10-12 21:56:19.209913: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# =============================================================================
# EXPERIMENT CONFIGURATION - CHANGE ONLY HERE!
# =============================================================================
import numpy as np
# Experiment identification
EXPERIMENT_NAME = "gs_wide_focal"  # Will be used in model names and logs
EXPERIMENT_DESCRIPTION = "Testing GS wide with focal loss"  # For documentation

# Model architecture
MODEL_TYPE = "grayscale"  # "rgb" or "grayscale"
ARCHITECTURE_TYPE = "complex"  # "simple" or "complex"

# Architecture parameters
if ARCHITECTURE_TYPE == "complex":
    CHANNELS = (96, 192, 512, 512, 192)
    CONVS_PER_BLOCK = 2
else:
    CHANNELS = (32, 64, 128)
    CONVS_PER_BLOCK = 1

# Regularization parameters
DROPOUT_HEAD = 0.35
L2_REG = 0.0005

# Loss
# Fixed class order and weights (from main notebook)
CLASS_ORDER = ['happy', 'neutral', 'sad', 'surprise']
CLASS_WEIGHTS = {
    0: 0.950,  # happy
    1: 0.950,  # neutral  
    2: 0.949,  # sad
    3: 1.190   # surprise
}

alpha_raw = np.array([CLASS_WEIGHTS[i] for i in range(len(CLASS_ORDER))], dtype=np.float32)
alpha_mean = alpha_raw.mean()
alpha_vec = alpha_raw / alpha_mean

LOSS = sparse_focal_loss(gamma=2.0, alpha=alpha_vec)
LABEL_SMOOTHING = 0.0
USE_CLASS_WEIGHT = False

# Training parameters
LEARNING_RATE = 0.0001
EPOCHS = 50
BATCH_SIZE = 64
PATIENCE = 10  # Early stopping patience

# Data parameters
IMG_SIZE = (48, 48)
COLOR_MODE = "rgb" if MODEL_TYPE == "rgb" else "grayscale"
AUGMENT = True

# Auto-generated names
MODEL_NAME = f"{ARCHITECTURE_TYPE}_cnn_{MODEL_TYPE}_{EXPERIMENT_NAME}"
RUN_DIR_NAME = f"{MODEL_TYPE}_{EXPERIMENT_NAME}"

# Display configuration
print("=" * 80)
print(f"EXPERIMENT: {EXPERIMENT_NAME}")
print("=" * 80)
print(f"Description: {EXPERIMENT_DESCRIPTION}")
print(f"Model type: {MODEL_TYPE}")
print(f"Architecture: {ARCHITECTURE_TYPE} - {CHANNELS}")
print(f"Image size: {IMG_SIZE}")
print(f"Color mode: {COLOR_MODE}")
print(f"Dropout: {DROPOUT_HEAD}")
print(f"L2 reg: {L2_REG}")
print(f"Learning rate: {LEARNING_RATE}")
print(f"Epochs: {EPOCHS}")
print(f"Batch size: {BATCH_SIZE}")
print(f"Augmentation: {AUGMENT}")
print(f"Model name: {MODEL_NAME}")
print("=" * 80)
# Out:
# ================================================================================
# EXPERIMENT: gs_wide_focal
# ================================================================================
# Description: Testing GS wide with focal loss
# Model type: grayscale
# Architecture: complex - (96, 192, 512, 512, 192)
# Image size: (48, 48)
# Color mode: grayscale
# Dropout: 0.35
# L2 reg: 0.0005
# Learning rate: 0.0001
# Epochs: 50
# Batch size: 64
# Augmentation: True
# Model name: complex_cnn_grayscale_gs_wide_focal
# ================================================================================
# 2025-10-12 21:56:20.602500: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-10-12 21:56:20.607471: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-10-12 21:56:20.607495: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-10-12 21:56:20.612861: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-10-12 21:56:20.612890: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-10-12 21:56:20.612900: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-10-12 21:56:20.723887: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-10-12 21:56:20.723921: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-10-12 21:56:20.723926: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2022] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2025-10-12 21:56:20.723938: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2025-10-12 21:56:20.723949: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-10-12 21:56:20.723972: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9509 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4080 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9

# %%
# =============================================================================
# IMPORTS AND SETUP
# =============================================================================

import warnings
import os
warnings.filterwarnings('ignore')
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
import time
import json
from pathlib import Path

from sklearn.metrics import classification_report, confusion_matrix, f1_score
from sklearn.utils.class_weight import compute_class_weight 

import tensorflow as tf
import keras
from keras import layers
from keras.utils import image_dataset_from_directory

# Fixed random seed for reproducibility
RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)
tf.random.set_seed(RANDOM_SEED)

print(f"TensorFlow version: {tf.__version__}")
print(f"GPU available: {tf.config.list_physical_devices('GPU')}")
print(f"Random seed: {RANDOM_SEED}")
# Out:
# TensorFlow version: 2.15.0
# GPU available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Random seed: 42

# %%
# =============================================================================
# CONSTANTS AND PATHS
# =============================================================================

# Data paths
DATA_DIR = Path("../../data")
TRAIN_DATA_DIR = Path("../../data/train")
VALIDATION_DATA_DIR = Path("../../data/validation")
TEST_DATA_DIR = Path("../../data/test")

# Output paths
MODELS_DIR = Path("../../models")
RUNS_DIR = Path("../../runs")
REPORTS_DIR = Path("../../reports")
SUMMARY_CSV = REPORTS_DIR / "models_summary.csv"

# Model parameters
NUM_CLASSES = 4
METRIC_NAME = "sparse_categorical_accuracy"
VAL_METRIC_NAME = f"val_{METRIC_NAME}"

print("Setup complete!")
print(f"Class order: {CLASS_ORDER}")
print(f"Class weights: {CLASS_WEIGHTS}")
# Out:
# Setup complete!
# Class order: ['happy', 'neutral', 'sad', 'surprise']
# Class weights: {0: 0.95, 1: 0.95, 2: 0.949, 3: 1.19}

# %%
# =============================================================================
# UTILITY FUNCTIONS
# =============================================================================

def save_metrics(metrics: dict, out_json: Path):
    """Save metrics to JSON file."""
    with open(out_json, "w") as f:
        json.dump(metrics, f, indent=2)

def make_run_dir(name: str) -> Path:
    """Create unique directory for experiment."""
    ts = datetime.now().strftime("%Y%m%d-%H%M%S")
    run_dir = RUNS_DIR / f"{ts}_{name}"
    (run_dir / "figs").mkdir(parents=True, exist_ok=True)
    return run_dir

def print_dict_table(d: dict, title="Dictionary", val_header="Value", show_percent=False, value_decimals=3):
    """Print dictionary as formatted table."""
    print(f"\n{title}")
    print(f"{'Class':<8} {val_header}")
    print("-" * (8 + len(val_header) + 2))
    total = sum(d.values()) if show_percent else None
    
    for key, value in d.items():
        if show_percent and total:
            pct = f" ({value/total*100:.1f}%)"
            print(f"{key:<8} {value:.{value_decimals}f}{pct}")
        else:
            print(f"{key:<8} {value:.{value_decimals}f}")
    
    if show_percent and total:
        print("-" * (8 + len(val_header) + 2))
        print(f"{'TOTAL':<8} {total:.{value_decimals}f}")
    print()

print("Utility functions loaded!")
# Out:
# Utility functions loaded!

# %%
# =============================================================================
# DATA LOADERS
# =============================================================================

def make_generators(train_dir, val_dir, test_dir, img_size=(48,48),
                    color_mode="grayscale", batch_size=64, augment=True):
    """Create data generators with fixed class order."""
    
    def preprocess_image(image, label):
        image = tf.cast(image, tf.float32) / 255.0
        return image, label
    
    def augment_image_simple(image, label):
        image = tf.image.random_flip_left_right(image)
        image = tf.image.random_brightness(image, 0.2)
        image = tf.image.random_contrast(image, 0.8, 1.2)
        image = tf.clip_by_value(image, 0.0, 1.0)
        return image, label
    
    print("Creating data loaders...")
    
    # Train data
    train_ds = image_dataset_from_directory(
        train_dir,
        class_names=CLASS_ORDER,
        image_size=img_size,
        batch_size=batch_size,
        color_mode=color_mode,
        shuffle=True
    )
    train_ds = train_ds.map(preprocess_image)
    if augment:
        train_ds = train_ds.map(augment_image_simple)
    
    # Validation data
    val_ds = image_dataset_from_directory(
        val_dir,
        class_names=CLASS_ORDER,
        image_size=img_size,
        batch_size=batch_size,
        color_mode=color_mode,
        shuffle=False
    )
    val_ds = val_ds.map(preprocess_image)
    
    # Test data
    test_ds = image_dataset_from_directory(
        test_dir,
        class_names=CLASS_ORDER,
        image_size=img_size,
        batch_size=batch_size,
        color_mode=color_mode,
        shuffle=False
    )
    test_ds = test_ds.map(preprocess_image)
    
    return train_ds, val_ds, test_ds

# Create data loaders
train_ds, val_ds, test_ds = make_generators(
    train_dir=TRAIN_DATA_DIR,
    val_dir=VALIDATION_DATA_DIR,
    test_dir=TEST_DATA_DIR,
    img_size=IMG_SIZE,
    color_mode=COLOR_MODE,
    batch_size=BATCH_SIZE,
    augment=AUGMENT
)

# Data sanity check
for xb, yb in train_ds.take(1):
    break

print(f"\nData loaded successfully!")
print(f"Train batch shape: {xb.shape}")
print(f"Labels shape: {yb.shape}")
print(f"Image range: [{tf.reduce_min(xb):.3f}, {tf.reduce_max(xb):.3f}]")
print(f"Unique labels: {tf.unique(yb)[0].numpy()}")
print(f"Augmentation: {AUGMENT}")
# Out:
# Creating data loaders...
# Found 15109 files belonging to 4 classes.
# Found 4977 files belonging to 4 classes.
# Found 128 files belonging to 4 classes.
#
# Data loaded successfully!
# Train batch shape: (64, 48, 48, 1)
# Labels shape: (64,)
# Image range: [0.000, 0.993]
# Unique labels: [0 2 3 1]
# Augmentation: True

# %%
# =============================================================================
# MODEL ARCHITECTURE
# =============================================================================

def build_cnn(input_shape, num_classes, channels=(64, 128, 256), 
               convs_per_block=2, dropout_head=0.3, activation="relu",
               l2_reg=0.001, lr=0.001, loss="sparse_categorical_crossentropy",
               label_smoothing=0.0):
    """Build CNN model with configurable architecture."""
    
    # Input layer
    inputs = keras.Input(shape=input_shape, name="input")
    x = inputs
    
    # Convolutional blocks
    for i, filters in enumerate(channels):
        for j in range(convs_per_block):
            x = layers.Conv2D(
                filters, 3, padding="same",
                kernel_regularizer=keras.regularizers.l2(l2_reg),
                name=f"conv_{i+1}_{j+1}"
            )(x)
            x = layers.BatchNormalization(name=f"bn_{i+1}_{j+1}")(x)
            
            if activation == "leakyrelu":
                x = layers.LeakyReLU(name=f"leaky_re_lu_{i+1}_{j+1}" if i==0 and j==0 else f"leaky_re_lu_{i+1}_{j+1}")(x)
            else:
                x = layers.Activation("relu", name=f"activation_{i+1}_{j+1}")(x)
        
        # Max pooling after each block (except last)
        if i < len(channels) - 1:
            x = layers.MaxPooling2D(2, name=f"pool_{i+1}")(x)
    
    # Global average pooling
    x = layers.GlobalAveragePooling2D(name="global_avg_pool")(x)
    
    # Dropout
    x = layers.Dropout(dropout_head, name="dropout_head")(x)
    
    # Output layer
    outputs = layers.Dense(num_classes, activation="softmax", name="output")(x)
    
    # Create model
    model = keras.Model(inputs, outputs, name="emotion_cnn")

    # configure loss
    if callable(LOSS):
        loss_fn = LOSS
    elif loss == "sparse_categorical_crossentropy":
        loss_fn = keras.losses.SparseCategoricalCrossentropy(
            label_smoothing=LABEL_SMOOTHING
        )
    else:
        loss_fn = LOSS  # e.g. built-in string losses    
    
    # Compile
    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=lr),
        loss=loss_fn,
        metrics=[METRIC_NAME]
    )
    
    return model

# Create model
input_shape = (*IMG_SIZE, 3 if MODEL_TYPE == "rgb" else 1)
model = build_cnn(
    input_shape=input_shape,
    num_classes=NUM_CLASSES,
    channels=CHANNELS,
    convs_per_block=CONVS_PER_BLOCK,
    dropout_head=DROPOUT_HEAD,
    activation="leakyrelu",
    l2_reg=L2_REG,
    lr=LEARNING_RATE
)

print(f"\nModel created: {MODEL_NAME}")
print(f"Input shape: {input_shape}")
print(f"Parameters: {model.count_params():,}")
model.summary()
# Out:
# Model created: complex_cnn_grayscale_gs_wide_focal
# Input shape: (48, 48, 1)
# Parameters: 9,776,420
# Model: "emotion_cnn"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 48, 48, 1)]       0
#
#  conv_1_1 (Conv2D)           (None, 48, 48, 96)        960
#
#  bn_1_1 (BatchNormalization  (None, 48, 48, 96)        384
#  )
#
#  leaky_re_lu_1_1 (LeakyReLU  (None, 48, 48, 96)        0
#  )
#
#  conv_1_2 (Conv2D)           (None, 48, 48, 96)        83040
#
#  bn_1_2 (BatchNormalization  (None, 48, 48, 96)        384
#  )
#
#  leaky_re_lu_1_2 (LeakyReLU  (None, 48, 48, 96)        0
#  )
#
#  pool_1 (MaxPooling2D)       (None, 24, 24, 96)        0
#
#  conv_2_1 (Conv2D)           (None, 24, 24, 192)       166080
#
#  bn_2_1 (BatchNormalization  (None, 24, 24, 192)       768
#  )
#
#  leaky_re_lu_2_1 (LeakyReLU  (None, 24, 24, 192)       0
#  )
#
#  conv_2_2 (Conv2D)           (None, 24, 24, 192)       331968
#
#  bn_2_2 (BatchNormalization  (None, 24, 24, 192)       768
#  )
#
#  leaky_re_lu_2_2 (LeakyReLU  (None, 24, 24, 192)       0
#  )
#
#  pool_2 (MaxPooling2D)       (None, 12, 12, 192)       0
#
#  conv_3_1 (Conv2D)           (None, 12, 12, 512)       885248
#
#  bn_3_1 (BatchNormalization  (None, 12, 12, 512)       2048
#  )
#
#  leaky_re_lu_3_1 (LeakyReLU  (None, 12, 12, 512)       0
#  )
#
#  conv_3_2 (Conv2D)           (None, 12, 12, 512)       2359808
#
#  bn_3_2 (BatchNormalization  (None, 12, 12, 512)       2048
#  )
#
#  leaky_re_lu_3_2 (LeakyReLU  (None, 12, 12, 512)       0
#  )
#
#  pool_3 (MaxPooling2D)       (None, 6, 6, 512)         0
#
#  conv_4_1 (Conv2D)           (None, 6, 6, 512)         2359808
#
#  bn_4_1 (BatchNormalization  (None, 6, 6, 512)         2048
#  )
#
#  leaky_re_lu_4_1 (LeakyReLU  (None, 6, 6, 512)         0
#  )
#
#  conv_4_2 (Conv2D)           (None, 6, 6, 512)         2359808
#
#  bn_4_2 (BatchNormalization  (None, 6, 6, 512)         2048
#  )
#
#  leaky_re_lu_4_2 (LeakyReLU  (None, 6, 6, 512)         0
#  )
#
#  pool_4 (MaxPooling2D)       (None, 3, 3, 512)         0
#
#  conv_5_1 (Conv2D)           (None, 3, 3, 192)         884928
#
#  bn_5_1 (BatchNormalization  (None, 3, 3, 192)         768
#  )
#
#  leaky_re_lu_5_1 (LeakyReLU  (None, 3, 3, 192)         0
#  )
#
#  conv_5_2 (Conv2D)           (None, 3, 3, 192)         331968
#
#  bn_5_2 (BatchNormalization  (None, 3, 3, 192)         768
#  )
#
#  leaky_re_lu_5_2 (LeakyReLU  (None, 3, 3, 192)         0
#  )
#
#  global_avg_pool (GlobalAve  (None, 192)               0
#  ragePooling2D)
#
#  dropout_head (Dropout)      (None, 192)               0
#
#  output (Dense)              (None, 4)                 772
#
# =================================================================
# Total params: 9776420 (37.29 MB)
# Trainable params: 9770404 (37.27 MB)
# Non-trainable params: 6016 (23.50 KB)
# _________________________________________________________________

# %%
# =============================================================================
# TRAINING
# =============================================================================

# Create callbacks
callbacks = [
    keras.callbacks.EarlyStopping(
        monitor="val_loss",
        patience=PATIENCE,
        restore_best_weights=True,
        verbose=1
    ),
    
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss",
        factor=0.5,
        patience=5,
        min_lr=1e-7,
        verbose=1
    ),
    
    keras.callbacks.ModelCheckpoint(
        filepath=str(MODELS_DIR / f"best_{MODEL_NAME}.keras"),
        monitor=VAL_METRIC_NAME,
        save_best_only=True,
        mode='max',
        verbose=1
    )
]

# Create run directory
run_dir = make_run_dir(RUN_DIR_NAME)

# Training configuration
print("=" * 70)
print(f"TRAINING CONFIGURATION - {MODEL_NAME}")
print("=" * 70)
print(f"Epochs: {EPOCHS}")
print(f"Batch size: {BATCH_SIZE}")
print(f"Learning rate: {LEARNING_RATE}")
print(f"Dropout: {DROPOUT_HEAD}")
print(f"L2 reg: {L2_REG}")
print(f"Class weights: {CLASS_WEIGHTS}")
print("=" * 70)

# Start training
start_time = time.time()
start_str = datetime.now().strftime("%Y-%m-%d %H:%M:%S")

print(f"\nTraining started at: {start_str}")

fit_class_weight = CLASS_WEIGHTS if USE_CLASS_WEIGHT else None
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=callbacks,
    class_weight=fit_class_weight,
    verbose=1
)

end_time = time.time()
training_time = end_time - start_time

print(f"\nTraining completed in {training_time/60:.1f} minutes")
# Out:
# ======================================================================
# TRAINING CONFIGURATION - complex_cnn_grayscale_gs_wide_focal
# ======================================================================
# Epochs: 50
# Batch size: 64
# Learning rate: 0.0001
# Dropout: 0.35
# L2 reg: 0.0005
# Class weights: {0: 0.95, 1: 0.95, 2: 0.949, 3: 1.19}
# ======================================================================
#
# Training started at: 2025-10-12 21:57:52
# Epoch 1/50
# 2025-10-12 21:57:55.025827: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8906
# 2025-10-12 21:57:57.514015: I external/local_xla/xla/service/service.cc:168] XLA service 0x7fb72979e860 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-10-12 21:57:57.514051: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 4080 Laptop GPU, Compute Capability 8.9
# 2025-10-12 21:57:57.518017: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1760306277.570027   69548 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 237/237 [==============================] - ETA: 0s - loss: 2.1279 - sparse_categorical_accuracy: 0.2483
# Epoch 1: val_sparse_categorical_accuracy improved from -inf to 0.22885, saving model to ../../models/best_complex_cnn_grayscale_gs_wide_focal.keras
# 237/237 [==============================] - 22s 61ms/step - loss: 2.1279 - sparse_categorical_accuracy: 0.2483 - val_loss: 1.9790 - val_sparse_categorical_accuracy: 0.2289 - lr: 1.0000e-04
# Epoch 2/50
# 235/237 [============================>.] - ETA: 0s - loss: 1.9231 - sparse_categorical_accuracy: 0.2477
# Epoch 2: val_sparse_categorical_accuracy improved from 0.22885 to 0.36287, saving model to ../../models/best_complex_cnn_grayscale_gs_wide_focal.keras
# 237/237 [==============================] - 12s 49ms/step - loss: 1.9227 - sparse_categorical_accuracy: 0.2477 - val_loss: 1.7704 - val_sparse_categorical_accuracy: 0.3629 - lr: 1.0000e-04
# Epoch 3/50
# 236/237 [============================>.] - ETA: 0s - loss: 1.7040 - sparse_categorical_accuracy: 0.2455
# Epoch 3: val_sparse_categorical_accuracy improved from 0.36287 to 0.36669, saving model to ../../models/best_complex_cnn_grayscale_gs_wide_focal.keras
# 237/237 [==============================] - 12s 48ms/step - loss: 1.7039 - sparse_categorical_accuracy: 0.2454 - val_loss: 1.5549 - val_sparse_categorical_accuracy: 0.3667 - lr: 1.0000e-04
# Epoch 4/50
# 235/237 [============================>.] - ETA: 0s - loss: 1.4954 - sparse_categorical_accuracy: 0.2547
# Epoch 4: val_sparse_categorical_accuracy did not improve from 0.36669
# 237/237 [==============================] - 12s 48ms/step - loss: 1.4949 - sparse_categorical_accuracy: 0.2549 - val_loss: 1.3609 - val_sparse_categorical_accuracy: 0.3653 - lr: 1.0000e-04
# Epoch 5/50
# 235/237 [============================>.] - ETA: 0s - loss: 1.3115 - sparse_categorical_accuracy: 0.2594
# Epoch 5: val_sparse_categorical_accuracy did not improve from 0.36669
# 237/237 [==============================] - 11s 44ms/step - loss: 1.3111 - sparse_categorical_accuracy: 0.2596 - val_loss: 1.2126 - val_sparse_categorical_accuracy: 0.2708 - lr: 1.0000e-04
# Epoch 6/50
# 235/237 [============================>.] - ETA: 0s - loss: 1.1607 - sparse_categorical_accuracy: 0.2506
# Epoch 6: val_sparse_categorical_accuracy did not improve from 0.36669
# 237/237 [==============================] - 11s 43ms/step - loss: 1.1604 - sparse_categorical_accuracy: 0.2505 - val_loss: 1.0710 - val_sparse_categorical_accuracy: 0.3599 - lr: 1.0000e-04
# Epoch 7/50
# 235/237 [============================>.] - ETA: 0s - loss: 1.0492 - sparse_categorical_accuracy: 0.2481
# Epoch 7: val_sparse_categorical_accuracy did not improve from 0.36669
# 237/237 [==============================] - 11s 44ms/step - loss: 1.0490 - sparse_categorical_accuracy: 0.2480 - val_loss: 0.9895 - val_sparse_categorical_accuracy: 0.3293 - lr: 1.0000e-04
# Epoch 8/50
# 235/237 [============================>.] - ETA: 0s - loss: 0.9707 - sparse_categorical_accuracy: 0.2508
# Epoch 8: val_sparse_categorical_accuracy did not improve from 0.36669
# 237/237 [==============================] - 11s 45ms/step - loss: 0.9706 - sparse_categorical_accuracy: 0.2507 - val_loss: 0.9218 - val_sparse_categorical_accuracy: 0.3144 - lr: 1.0000e-04
# Epoch 9/50
# 235/237 [============================>.] - ETA: 0s - loss: 0.9167 - sparse_categorical_accuracy: 0.2487
# Epoch 9: val_sparse_categorical_accuracy did not improve from 0.36669
# 237/237 [==============================] - 11s 43ms/step - loss: 0.9166 - sparse_categorical_accuracy: 0.2488 - val_loss: 0.8810 - val_sparse_categorical_accuracy: 0.2202 - lr: 1.0000e-04
# Epoch 10/50
# 235/237 [============================>.] - ETA: 0s - loss: 0.8792 - sparse_categorical_accuracy: 0.2545
# Epoch 10: val_sparse_categorical_accuracy did not improve from 0.36669
# 237/237 [==============================] - 10s 43ms/step - loss: 0.8791 - sparse_categorical_accuracy: 0.2545 - val_loss: 0.8494 - val_sparse_categorical_accuracy: 0.3237 - lr: 1.0000e-04
# Epoch 11/50
# 235/237 [============================>.] - ETA: 0s - loss: 0.8534 - sparse_categorical_accuracy: 0.2523
# Epoch 11: val_sparse_categorical_accuracy improved from 0.36669 to 0.36709, saving model to ../../models/best_complex_cnn_grayscale_gs_wide_focal.keras
# 237/237 [==============================] - 12s 50ms/step - loss: 0.8534 - sparse_categorical_accuracy: 0.2520 - val_loss: 0.8255 - val_sparse_categorical_accuracy: 0.3671 - lr: 1.0000e-04
# Epoch 12/50
# 235/237 [============================>.] - ETA: 0s - loss: 0.8358 - sparse_categorical_accuracy: 0.2435
# Epoch 12: val_sparse_categorical_accuracy did not improve from 0.36709
# 237/237 [==============================] - 11s 46ms/step - loss: 0.8359 - sparse_categorical_accuracy: 0.2434 - val_loss: 0.8156 - val_sparse_categorical_accuracy: 0.3102 - lr: 1.0000e-04
# Epoch 13/50
# 235/237 [============================>.] - ETA: 0s - loss: 0.8223 - sparse_categorical_accuracy: 0.2507
# Epoch 13: val_sparse_categorical_accuracy did not improve from 0.36709
# 237/237 [==============================] - 11s 46ms/step - loss: 0.8222 - sparse_categorical_accuracy: 0.2510 - val_loss: 0.8039 - val_sparse_categorical_accuracy: 0.2614 - lr: 1.0000e-04
# Epoch 14/50
# 235/237 [============================>.] - ETA: 0s - loss: 0.8161 - sparse_categorical_accuracy: 0.2475
# Epoch 14: val_sparse_categorical_accuracy did not improve from 0.36709
# 237/237 [==============================] - 11s 45ms/step - loss: 0.8161 - sparse_categorical_accuracy: 0.2475 - val_loss: 0.7980 - val_sparse_categorical_accuracy: 0.3546 - lr: 1.0000e-04
# Epoch 15/50
# 237/237 [==============================] - ETA: 0s - loss: 0.8123 - sparse_categorical_accuracy: 0.2442
# Epoch 15: val_sparse_categorical_accuracy did not improve from 0.36709
# 237/237 [==============================] - 11s 47ms/step - loss: 0.8123 - sparse_categorical_accuracy: 0.2442 - val_loss: 0.7933 - val_sparse_categorical_accuracy: 0.3175 - lr: 1.0000e-04
# Epoch 16/50
# 236/237 [============================>.] - ETA: 0s - loss: 0.8040 - sparse_categorical_accuracy: 0.2494
# Epoch 16: val_sparse_categorical_accuracy did not improve from 0.36709
# 237/237 [==============================] - 12s 48ms/step - loss: 0.8040 - sparse_categorical_accuracy: 0.2495 - val_loss: 0.7875 - val_sparse_categorical_accuracy: 0.3367 - lr: 1.0000e-04
# Epoch 17/50
# 235/237 [============================>.] - ETA: 0s - loss: 0.8026 - sparse_categorical_accuracy: 0.2481
# Epoch 17: val_sparse_categorical_accuracy improved from 0.36709 to 0.37071, saving model to ../../models/best_complex_cnn_grayscale_gs_wide_focal.keras
# 237/237 [==============================] - 12s 50ms/step - loss: 0.8026 - sparse_categorical_accuracy: 0.2480 - val_loss: 0.7813 - val_sparse_categorical_accuracy: 0.3707 - lr: 1.0000e-04
# Epoch 18/50
# 236/237 [============================>.] - ETA: 0s - loss: 0.7968 - sparse_categorical_accuracy: 0.2452
# Epoch 18: val_sparse_categorical_accuracy did not improve from 0.37071
# 237/237 [==============================] - 11s 45ms/step - loss: 0.7968 - sparse_categorical_accuracy: 0.2451 - val_loss: 0.7809 - val_sparse_categorical_accuracy: 0.3667 - lr: 1.0000e-04
# Epoch 19/50
# 235/237 [============================>.] - ETA: 0s - loss: 0.7953 - sparse_categorical_accuracy: 0.2471
# Epoch 19: val_sparse_categorical_accuracy did not improve from 0.37071
# 237/237 [==============================] - 11s 45ms/step - loss: 0.7953 - sparse_categorical_accuracy: 0.2471 - val_loss: 0.7828 - val_sparse_categorical_accuracy: 0.2299 - lr: 1.0000e-04
# Epoch 20/50
# 235/237 [============================>.] - ETA: 0s - loss: 0.7947 - sparse_categorical_accuracy: 0.2504
# Epoch 20: val_sparse_categorical_accuracy did not improve from 0.37071
# 237/237 [==============================] - 11s 45ms/step - loss: 0.7947 - sparse_categorical_accuracy: 0.2502 - val_loss: 0.7769 - val_sparse_categorical_accuracy: 0.3655 - lr: 1.0000e-04
# Epoch 21/50
# 237/237 [==============================] - ETA: 0s - loss: 0.7936 - sparse_categorical_accuracy: 0.2494
# Epoch 21: val_sparse_categorical_accuracy did not improve from 0.37071
# 237/237 [==============================] - 11s 46ms/step - loss: 0.7936 - sparse_categorical_accuracy: 0.2494 - val_loss: 0.7767 - val_sparse_categorical_accuracy: 0.3647 - lr: 1.0000e-04
# Epoch 22/50
# 235/237 [============================>.] - ETA: 0s - loss: 0.7918 - sparse_categorical_accuracy: 0.2464
# Epoch 22: val_sparse_categorical_accuracy did not improve from 0.37071
# 237/237 [==============================] - 11s 45ms/step - loss: 0.7919 - sparse_categorical_accuracy: 0.2463 - val_loss: 0.7743 - val_sparse_categorical_accuracy: 0.3669 - lr: 1.0000e-04
# Epoch 23/50
# 235/237 [============================>.] - ETA: 0s - loss: 0.7885 - sparse_categorical_accuracy: 0.2446
# Epoch 23: val_sparse_categorical_accuracy did not improve from 0.37071
# 237/237 [==============================] - 11s 45ms/step - loss: 0.7886 - sparse_categorical_accuracy: 0.2454 - val_loss: 0.7717 - val_sparse_categorical_accuracy: 0.2662 - lr: 1.0000e-04
# Epoch 24/50
# 235/237 [============================>.] - ETA: 0s - loss: 0.7883 - sparse_categorical_accuracy: 0.2464
# Epoch 24: val_sparse_categorical_accuracy did not improve from 0.37071
# 237/237 [==============================] - 11s 44ms/step - loss: 0.7883 - sparse_categorical_accuracy: 0.2465 - val_loss: 0.7741 - val_sparse_categorical_accuracy: 0.2743 - lr: 1.0000e-04
# Epoch 25/50
# 235/237 [============================>.] - ETA: 0s - loss: 0.7864 - sparse_categorical_accuracy: 0.2523
# Epoch 25: val_sparse_categorical_accuracy did not improve from 0.37071
# 237/237 [==============================] - 11s 44ms/step - loss: 0.7865 - sparse_categorical_accuracy: 0.2522 - val_loss: 0.7722 - val_sparse_categorical_accuracy: 0.3661 - lr: 1.0000e-04
# Epoch 26/50
# 235/237 [============================>.] - ETA: 0s - loss: 0.7855 - sparse_categorical_accuracy: 0.2513
# Epoch 26: val_sparse_categorical_accuracy did not improve from 0.37071
# 237/237 [==============================] - 11s 45ms/step - loss: 0.7855 - sparse_categorical_accuracy: 0.2515 - val_loss: 0.7706 - val_sparse_categorical_accuracy: 0.3446 - lr: 1.0000e-04
# Epoch 27/50
# 235/237 [============================>.] - ETA: 0s - loss: 0.7845 - sparse_categorical_accuracy: 0.2488
# Epoch 27: val_sparse_categorical_accuracy did not improve from 0.37071
# 237/237 [==============================] - 11s 45ms/step - loss: 0.7844 - sparse_categorical_accuracy: 0.2491 - val_loss: 0.7750 - val_sparse_categorical_accuracy: 0.3040 - lr: 1.0000e-04
# Epoch 28/50
# 237/237 [==============================] - ETA: 0s - loss: 0.7853 - sparse_categorical_accuracy: 0.2480
# Epoch 28: val_sparse_categorical_accuracy did not improve from 0.37071
# 237/237 [==============================] - 11s 44ms/step - loss: 0.7853 - sparse_categorical_accuracy: 0.2480 - val_loss: 0.7685 - val_sparse_categorical_accuracy: 0.3566 - lr: 1.0000e-04
# Epoch 29/50
# 237/237 [==============================] - ETA: 0s - loss: 0.7844 - sparse_categorical_accuracy: 0.2491
# Epoch 29: val_sparse_categorical_accuracy did not improve from 0.37071
# 237/237 [==============================] - 12s 48ms/step - loss: 0.7844 - sparse_categorical_accuracy: 0.2491 - val_loss: 0.7696 - val_sparse_categorical_accuracy: 0.3500 - lr: 1.0000e-04
# Epoch 30/50
# 235/237 [============================>.] - ETA: 0s - loss: 0.7932 - sparse_categorical_accuracy: 0.2511
# Epoch 30: val_sparse_categorical_accuracy did not improve from 0.37071
# 237/237 [==============================] - 11s 46ms/step - loss: 0.7932 - sparse_categorical_accuracy: 0.2511 - val_loss: 0.7924 - val_sparse_categorical_accuracy: 0.2305 - lr: 1.0000e-04
# Epoch 31/50
# 235/237 [============================>.] - ETA: 0s - loss: 0.7879 - sparse_categorical_accuracy: 0.2469
# Epoch 31: val_sparse_categorical_accuracy did not improve from 0.37071
# 237/237 [==============================] - 12s 48ms/step - loss: 0.7879 - sparse_categorical_accuracy: 0.2472 - val_loss: 0.7704 - val_sparse_categorical_accuracy: 0.3580 - lr: 1.0000e-04
# Epoch 32/50
# 235/237 [============================>.] - ETA: 0s - loss: 0.7840 - sparse_categorical_accuracy: 0.2546
# Epoch 32: val_sparse_categorical_accuracy did not improve from 0.37071
# 237/237 [==============================] - 11s 46ms/step - loss: 0.7840 - sparse_categorical_accuracy: 0.2545 - val_loss: 0.7698 - val_sparse_categorical_accuracy: 0.3542 - lr: 1.0000e-04
# Epoch 33/50
# 237/237 [==============================] - ETA: 0s - loss: 0.7827 - sparse_categorical_accuracy: 0.2482
# Epoch 33: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 33: val_sparse_categorical_accuracy did not improve from 0.37071
# 237/237 [==============================] - 11s 44ms/step - loss: 0.7827 - sparse_categorical_accuracy: 0.2482 - val_loss: 0.7686 - val_sparse_categorical_accuracy: 0.2636 - lr: 1.0000e-04
# Epoch 34/50
# 235/237 [============================>.] - ETA: 0s - loss: 0.7803 - sparse_categorical_accuracy: 0.2474
# Epoch 34: val_sparse_categorical_accuracy did not improve from 0.37071
# 237/237 [==============================] - 11s 45ms/step - loss: 0.7803 - sparse_categorical_accuracy: 0.2474 - val_loss: 0.7683 - val_sparse_categorical_accuracy: 0.2980 - lr: 5.0000e-05
# Epoch 35/50
# 235/237 [============================>.] - ETA: 0s - loss: 0.7794 - sparse_categorical_accuracy: 0.2509
# Epoch 35: val_sparse_categorical_accuracy did not improve from 0.37071
# 237/237 [==============================] - 11s 45ms/step - loss: 0.7795 - sparse_categorical_accuracy: 0.2510 - val_loss: 0.7692 - val_sparse_categorical_accuracy: 0.2646 - lr: 5.0000e-05
# Epoch 36/50
# 235/237 [============================>.] - ETA: 0s - loss: 0.7809 - sparse_categorical_accuracy: 0.2566
# Epoch 36: val_sparse_categorical_accuracy did not improve from 0.37071
# 237/237 [==============================] - 11s 43ms/step - loss: 0.7809 - sparse_categorical_accuracy: 0.2565 - val_loss: 0.7678 - val_sparse_categorical_accuracy: 0.2917 - lr: 5.0000e-05
# Epoch 37/50
# 235/237 [============================>.] - ETA: 0s - loss: 0.7800 - sparse_categorical_accuracy: 0.2485
# Epoch 37: val_sparse_categorical_accuracy did not improve from 0.37071
# 237/237 [==============================] - 11s 44ms/step - loss: 0.7799 - sparse_categorical_accuracy: 0.2484 - val_loss: 0.7683 - val_sparse_categorical_accuracy: 0.2483 - lr: 5.0000e-05
# Epoch 38/50
# 235/237 [============================>.] - ETA: 0s - loss: 0.7794 - sparse_categorical_accuracy: 0.2485
# Epoch 38: val_sparse_categorical_accuracy did not improve from 0.37071
# 237/237 [==============================] - 11s 45ms/step - loss: 0.7794 - sparse_categorical_accuracy: 0.2488 - val_loss: 0.7657 - val_sparse_categorical_accuracy: 0.3595 - lr: 5.0000e-05
# Epoch 39/50
# 235/237 [============================>.] - ETA: 0s - loss: 0.7787 - sparse_categorical_accuracy: 0.2495
# Epoch 39: val_sparse_categorical_accuracy did not improve from 0.37071
# 237/237 [==============================] - 11s 45ms/step - loss: 0.7787 - sparse_categorical_accuracy: 0.2495 - val_loss: 0.7656 - val_sparse_categorical_accuracy: 0.3625 - lr: 5.0000e-05
# Epoch 40/50
# 237/237 [==============================] - ETA: 0s - loss: 0.7785 - sparse_categorical_accuracy: 0.2483
# Epoch 40: val_sparse_categorical_accuracy did not improve from 0.37071
# 237/237 [==============================] - 11s 45ms/step - loss: 0.7785 - sparse_categorical_accuracy: 0.2483 - val_loss: 0.7686 - val_sparse_categorical_accuracy: 0.2873 - lr: 5.0000e-05
# Epoch 41/50
# 236/237 [============================>.] - ETA: 0s - loss: 0.7786 - sparse_categorical_accuracy: 0.2501
# Epoch 41: val_sparse_categorical_accuracy did not improve from 0.37071
# 237/237 [==============================] - 11s 47ms/step - loss: 0.7786 - sparse_categorical_accuracy: 0.2500 - val_loss: 0.7647 - val_sparse_categorical_accuracy: 0.3255 - lr: 5.0000e-05
# Epoch 42/50
# 235/237 [============================>.] - ETA: 0s - loss: 0.7790 - sparse_categorical_accuracy: 0.2495
# Epoch 42: val_sparse_categorical_accuracy did not improve from 0.37071
# 237/237 [==============================] - 11s 46ms/step - loss: 0.7791 - sparse_categorical_accuracy: 0.2498 - val_loss: 0.7644 - val_sparse_categorical_accuracy: 0.2449 - lr: 5.0000e-05
# Epoch 43/50
# 235/237 [============================>.] - ETA: 0s - loss: 0.7795 - sparse_categorical_accuracy: 0.2489
# Epoch 43: val_sparse_categorical_accuracy did not improve from 0.37071
# 237/237 [==============================] - 11s 44ms/step - loss: 0.7795 - sparse_categorical_accuracy: 0.2489 - val_loss: 0.7667 - val_sparse_categorical_accuracy: 0.3645 - lr: 5.0000e-05
# Epoch 44/50
# 235/237 [============================>.] - ETA: 0s - loss: 0.7786 - sparse_categorical_accuracy: 0.2535
# Epoch 44: val_sparse_categorical_accuracy did not improve from 0.37071
# 237/237 [==============================] - 11s 45ms/step - loss: 0.7786 - sparse_categorical_accuracy: 0.2534 - val_loss: 0.7780 - val_sparse_categorical_accuracy: 0.3104 - lr: 5.0000e-05
# Epoch 45/50
# 235/237 [============================>.] - ETA: 0s - loss: 0.7786 - sparse_categorical_accuracy: 0.2545
# Epoch 45: val_sparse_categorical_accuracy did not improve from 0.37071
# 237/237 [==============================] - 11s 46ms/step - loss: 0.7785 - sparse_categorical_accuracy: 0.2546 - val_loss: 0.7651 - val_sparse_categorical_accuracy: 0.3665 - lr: 5.0000e-05
# Epoch 46/50
# 235/237 [============================>.] - ETA: 0s - loss: 0.7782 - sparse_categorical_accuracy: 0.2483
# Epoch 46: val_sparse_categorical_accuracy did not improve from 0.37071
# 237/237 [==============================] - 11s 45ms/step - loss: 0.7782 - sparse_categorical_accuracy: 0.2484 - val_loss: 0.7648 - val_sparse_categorical_accuracy: 0.3518 - lr: 5.0000e-05
# Epoch 47/50
# 235/237 [============================>.] - ETA: 0s - loss: 0.7778 - sparse_categorical_accuracy: 0.2451
# Epoch 47: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
#
# Epoch 47: val_sparse_categorical_accuracy did not improve from 0.37071
# 237/237 [==============================] - 11s 45ms/step - loss: 0.7777 - sparse_categorical_accuracy: 0.2452 - val_loss: 0.7703 - val_sparse_categorical_accuracy: 0.3193 - lr: 5.0000e-05
# Epoch 48/50
# 235/237 [============================>.] - ETA: 0s - loss: 0.7772 - sparse_categorical_accuracy: 0.2490
# Epoch 48: val_sparse_categorical_accuracy did not improve from 0.37071
# 237/237 [==============================] - 11s 45ms/step - loss: 0.7772 - sparse_categorical_accuracy: 0.2493 - val_loss: 0.7656 - val_sparse_categorical_accuracy: 0.3516 - lr: 2.5000e-05
# Epoch 49/50
# 237/237 [==============================] - ETA: 0s - loss: 0.7773 - sparse_categorical_accuracy: 0.2491
# Epoch 49: val_sparse_categorical_accuracy did not improve from 0.37071
# 237/237 [==============================] - 11s 44ms/step - loss: 0.7773 - sparse_categorical_accuracy: 0.2491 - val_loss: 0.7660 - val_sparse_categorical_accuracy: 0.3615 - lr: 2.5000e-05
# Epoch 50/50
# 235/237 [============================>.] - ETA: 0s - loss: 0.7766 - sparse_categorical_accuracy: 0.2493
# Epoch 50: val_sparse_categorical_accuracy did not improve from 0.37071
# 237/237 [==============================] - 11s 47ms/step - loss: 0.7766 - sparse_categorical_accuracy: 0.2497 - val_loss: 0.7651 - val_sparse_categorical_accuracy: 0.3637 - lr: 2.5000e-05
#
# Training completed in 9.4 minutes

# %%
# =============================================================================
# EVALUATION
# =============================================================================

print("=" * 70)
print(f"EVALUATION - {MODEL_NAME}")
print("=" * 70)

# Get predictions
y_true = []
y_pred = []

for batch in test_ds:
    images, labels = batch
    predictions = model.predict(images, verbose=0)
    y_true.extend(labels.numpy())
    y_pred.extend(np.argmax(predictions, axis=1))

# Calculate metrics
test_accuracy = f1_score(y_true, y_pred, average='weighted')
test_macro_f1 = f1_score(y_true, y_pred, average='macro')
test_weighted_f1 = f1_score(y_true, y_pred, average='weighted')

# Display results
print(f"Test accuracy: {test_accuracy:.3f}")
print(f"Test macro F1: {test_macro_f1:.3f}")
print(f"Test weighted F1: {test_weighted_f1:.3f}")
print("=" * 70)

# Save results
results = {
    "experiment_name": EXPERIMENT_NAME,
    "experiment_description": EXPERIMENT_DESCRIPTION,
    "model_name": MODEL_NAME,
    "model_type": MODEL_TYPE,
    "architecture_type": ARCHITECTURE_TYPE,
    "channels": CHANNELS,
    "convs_per_block": CONVS_PER_BLOCK,
    "input_shape": list(input_shape),
    "dropout_head": DROPOUT_HEAD,
    "l2_reg": L2_REG,
    "learning_rate": LEARNING_RATE,
    "epochs": EPOCHS,
    "batch_size": BATCH_SIZE,
    "augment": AUGMENT,
    "training_time_minutes": training_time / 60,
    "test_accuracy": test_accuracy,
    "test_macro_f1": test_macro_f1,
    "test_weighted_f1": test_weighted_f1,
    "total_epochs_trained": len(history.history['loss']),
    "final_train_acc": history.history[METRIC_NAME][-1],
    "final_train_loss": history.history['loss'][-1],
    "final_val_acc": history.history[VAL_METRIC_NAME][-1],
    "final_val_loss": history.history['val_loss'][-1],
    "best_val_acc": max(history.history[VAL_METRIC_NAME]),
    "best_epoch": history.history[VAL_METRIC_NAME].index(max(history.history[VAL_METRIC_NAME])) + 1
}

# Save to run directory
save_metrics(results, run_dir / "experiment_results.json")
save_metrics(results, run_dir / "config.json")

print(f"\nResults saved to: {run_dir}")
print(f"Experiment completed: {EXPERIMENT_NAME}")
# Out:
# ======================================================================
# EVALUATION - complex_cnn_grayscale_gs_wide_focal
# ======================================================================
# Test accuracy: 0.100
# Test macro F1: 0.100
# Test weighted F1: 0.100
# ======================================================================
#
# Results saved to: ../../runs/20251012-215752_grayscale_gs_wide_focal
# Experiment completed: gs_wide_focal

# %%
# =============================================================================
# VISUALIZATION
# =============================================================================

# Plot training history
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

# Accuracy plot
axes[0].plot(history.history[METRIC_NAME], label='train', linewidth=2)
axes[0].plot(history.history[VAL_METRIC_NAME], label='validation', linewidth=2)
axes[0].set_title(f'Accuracy - {MODEL_NAME}')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Accuracy')
axes[0].legend()
axes[0].grid(True, alpha=0.3)

# Loss plot
axes[1].plot(history.history['loss'], label='train', linewidth=2)
axes[1].plot(history.history['val_loss'], label='validation', linewidth=2)
axes[1].set_title(f'Loss - {MODEL_NAME}')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Loss')
axes[1].legend()
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig(run_dir / "training_history.png", dpi=150, bbox_inches="tight")
plt.show()

# Confusion matrix
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.colorbar()

tick_marks = np.arange(len(CLASS_ORDER))
plt.xticks(tick_marks, CLASS_ORDER, rotation=45)
plt.yticks(tick_marks, CLASS_ORDER)

# Add text annotations
thresh = cm.max() / 2.
for i, j in np.ndindex(cm.shape):
    plt.text(j, i, cm[i, j], horizontalalignment="center",
             color="white" if cm[i, j] > thresh else "black", fontsize=10)

plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title(f'Confusion Matrix - {MODEL_NAME}')
plt.tight_layout()
plt.savefig(run_dir / "confusion_matrix.png", dpi=150, bbox_inches="tight")
plt.show()

print(f"Visualizations saved to: {run_dir}")
# Out:
# Visualizations saved to: ../../runs/20251012-215752_grayscale_gs_wide_focal
