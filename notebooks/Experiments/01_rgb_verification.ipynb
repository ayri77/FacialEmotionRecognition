# %% [markdown]
# # =============================================================================
# # FACIAL EMOTION RECOGNITION - EXPERIMENT TEMPLATE
# # =============================================================================
# #
# # Universal template for running experiments with different configurations
# # Change parameters in Cell 1 to run different experiments
# #
# # Author: Pavlo Borysov
# # Date: 12/10/2025
# # =============================================================================

# %%
# =============================================================================
# EXPERIMENT CONFIGURATION - CHANGE ONLY HERE!
# =============================================================================

# Experiment identification
EXPERIMENT_NAME = "rgb_verification"  # Will be used in model names and logs
EXPERIMENT_DESCRIPTION = "Verifying RGB results"  # For documentation

# Model architecture
MODEL_TYPE = "rgb"  # "rgb" or "grayscale"
ARCHITECTURE_TYPE = "complex"  # "simple" or "complex"

# Architecture parameters
if ARCHITECTURE_TYPE == "complex":
    CHANNELS = (64, 128, 512, 512, 128)
    CONVS_PER_BLOCK = 2
else:
    CHANNELS = (32, 64, 128)
    CONVS_PER_BLOCK = 1

# Regularization parameters
DROPOUT_HEAD = 0.3
L2_REG = 0.001

# Training parameters
LEARNING_RATE = 0.0001
EPOCHS = 50
BATCH_SIZE = 64
PATIENCE = 10  # Early stopping patience

# Data parameters
IMG_SIZE = (48, 48)
COLOR_MODE = "rgb" if MODEL_TYPE == "rgb" else "grayscale"
AUGMENT = True

# Auto-generated names
MODEL_NAME = f"{ARCHITECTURE_TYPE}_cnn_{MODEL_TYPE}_{EXPERIMENT_NAME}"
RUN_DIR_NAME = f"{MODEL_TYPE}_{EXPERIMENT_NAME}"

# Display configuration
print("=" * 80)
print(f"EXPERIMENT: {EXPERIMENT_NAME}")
print("=" * 80)
print(f"Description: {EXPERIMENT_DESCRIPTION}")
print(f"Model type: {MODEL_TYPE}")
print(f"Architecture: {ARCHITECTURE_TYPE} - {CHANNELS}")
print(f"Image size: {IMG_SIZE}")
print(f"Color mode: {COLOR_MODE}")
print(f"Dropout: {DROPOUT_HEAD}")
print(f"L2 reg: {L2_REG}")
print(f"Learning rate: {LEARNING_RATE}")
print(f"Epochs: {EPOCHS}")
print(f"Batch size: {BATCH_SIZE}")
print(f"Augmentation: {AUGMENT}")
print(f"Model name: {MODEL_NAME}")
print("=" * 80)
# Out:
# ================================================================================
# EXPERIMENT: rgb_verification
# ================================================================================
# Description: Verifying RGB results
# Model type: rgb
# Architecture: complex - (64, 128, 512, 512, 128)
# Image size: (48, 48)
# Color mode: rgb
# Dropout: 0.3
# L2 reg: 0.001
# Learning rate: 0.0001
# Epochs: 50
# Batch size: 64
# Augmentation: True
# Model name: complex_cnn_rgb_rgb_verification
# ================================================================================

# %%
# =============================================================================
# IMPORTS AND SETUP
# =============================================================================

import warnings
import os
warnings.filterwarnings('ignore')
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
import time
import json
from pathlib import Path

from sklearn.metrics import classification_report, confusion_matrix, f1_score
from sklearn.utils.class_weight import compute_class_weight 

import tensorflow as tf
import keras
from keras import layers
from keras.utils import image_dataset_from_directory

# Fixed random seed for reproducibility
RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)
tf.random.set_seed(RANDOM_SEED)

print(f"TensorFlow version: {tf.__version__}")
print(f"GPU available: {tf.config.list_physical_devices('GPU')}")
print(f"Random seed: {RANDOM_SEED}")
# Out:
# 2025-10-12 20:40:37.888196: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-10-12 20:40:37.888277: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-10-12 20:40:37.890723: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# TensorFlow version: 2.15.0
# GPU available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Random seed: 42

# %%
# =============================================================================
# CONSTANTS AND PATHS
# =============================================================================

# Data paths
DATA_DIR = Path("../../data")
TRAIN_DATA_DIR = Path("../../data/train")
VALIDATION_DATA_DIR = Path("../../data/validation")
TEST_DATA_DIR = Path("../../data/test")

# Output paths
MODELS_DIR = Path("../../models")
RUNS_DIR = Path("../../runs")
REPORTS_DIR = Path("../../reports")
SUMMARY_CSV = REPORTS_DIR / "models_summary.csv"

# Fixed class order and weights (from main notebook)
CLASS_ORDER = ['happy', 'neutral', 'sad', 'surprise']
CLASS_WEIGHTS = {
    0: 0.950,  # happy
    1: 0.950,  # neutral  
    2: 0.949,  # sad
    3: 1.190   # surprise
}

# Model parameters
NUM_CLASSES = 4
METRIC_NAME = "sparse_categorical_accuracy"
VAL_METRIC_NAME = f"val_{METRIC_NAME}"

print("Setup complete!")
print(f"Class order: {CLASS_ORDER}")
print(f"Class weights: {CLASS_WEIGHTS}")
# Out:
# Setup complete!
# Class order: ['happy', 'neutral', 'sad', 'surprise']
# Class weights: {0: 0.95, 1: 0.95, 2: 0.949, 3: 1.19}

# %%
# =============================================================================
# UTILITY FUNCTIONS
# =============================================================================

def save_metrics(metrics: dict, out_json: Path):
    """Save metrics to JSON file."""
    with open(out_json, "w") as f:
        json.dump(metrics, f, indent=2)

def make_run_dir(name: str) -> Path:
    """Create unique directory for experiment."""
    ts = datetime.now().strftime("%Y%m%d-%H%M%S")
    run_dir = RUNS_DIR / f"{ts}_{name}"
    (run_dir / "figs").mkdir(parents=True, exist_ok=True)
    return run_dir

def print_dict_table(d: dict, title="Dictionary", val_header="Value", show_percent=False, value_decimals=3):
    """Print dictionary as formatted table."""
    print(f"\n{title}")
    print(f"{'Class':<8} {val_header}")
    print("-" * (8 + len(val_header) + 2))
    total = sum(d.values()) if show_percent else None
    
    for key, value in d.items():
        if show_percent and total:
            pct = f" ({value/total*100:.1f}%)"
            print(f"{key:<8} {value:.{value_decimals}f}{pct}")
        else:
            print(f"{key:<8} {value:.{value_decimals}f}")
    
    if show_percent and total:
        print("-" * (8 + len(val_header) + 2))
        print(f"{'TOTAL':<8} {total:.{value_decimals}f}")
    print()

print("Utility functions loaded!")
# Out:
# Utility functions loaded!

# %%
# =============================================================================
# DATA LOADERS
# =============================================================================

def make_generators(train_dir, val_dir, test_dir, img_size=(48,48),
                    color_mode="grayscale", batch_size=64, augment=True):
    """Create data generators with fixed class order."""
    
    def preprocess_image(image, label):
        image = tf.cast(image, tf.float32) / 255.0
        return image, label
    
    def augment_image_simple(image, label):
        image = tf.image.random_flip_left_right(image)
        image = tf.image.random_brightness(image, 0.2)
        image = tf.image.random_contrast(image, 0.8, 1.2)
        image = tf.clip_by_value(image, 0.0, 1.0)
        return image, label
    
    print("Creating data loaders...")
    
    # Train data
    train_ds = image_dataset_from_directory(
        train_dir,
        class_names=CLASS_ORDER,
        image_size=img_size,
        batch_size=batch_size,
        color_mode=color_mode,
        shuffle=True
    )
    train_ds = train_ds.map(preprocess_image)
    if augment:
        train_ds = train_ds.map(augment_image_simple)
    
    # Validation data
    val_ds = image_dataset_from_directory(
        val_dir,
        class_names=CLASS_ORDER,
        image_size=img_size,
        batch_size=batch_size,
        color_mode=color_mode,
        shuffle=False
    )
    val_ds = val_ds.map(preprocess_image)
    
    # Test data
    test_ds = image_dataset_from_directory(
        test_dir,
        class_names=CLASS_ORDER,
        image_size=img_size,
        batch_size=batch_size,
        color_mode=color_mode,
        shuffle=False
    )
    test_ds = test_ds.map(preprocess_image)
    
    return train_ds, val_ds, test_ds

# Create data loaders
train_ds, val_ds, test_ds = make_generators(
    train_dir=TRAIN_DATA_DIR,
    val_dir=VALIDATION_DATA_DIR,
    test_dir=TEST_DATA_DIR,
    img_size=IMG_SIZE,
    color_mode=COLOR_MODE,
    batch_size=BATCH_SIZE,
    augment=AUGMENT
)

# Data sanity check
for xb, yb in train_ds.take(1):
    break

print(f"\nData loaded successfully!")
print(f"Train batch shape: {xb.shape}")
print(f"Labels shape: {yb.shape}")
print(f"Image range: [{tf.reduce_min(xb):.3f}, {tf.reduce_max(xb):.3f}]")
print(f"Unique labels: {tf.unique(yb)[0].numpy()}")
print(f"Augmentation: {AUGMENT}")
# Out:
# Creating data loaders...
# Found 15109 files belonging to 4 classes.
# Found 4977 files belonging to 4 classes.
# Found 128 files belonging to 4 classes.
#
# Data loaded successfully!
# Train batch shape: (64, 48, 48, 3)
# Labels shape: (64,)
# Image range: [0.000, 0.993]
# Unique labels: [0 2 3 1]
# Augmentation: True

# %%
# =============================================================================
# MODEL ARCHITECTURE
# =============================================================================

def build_cnn(input_shape, num_classes, channels=(64, 128, 256), 
               convs_per_block=2, dropout_head=0.3, activation="relu",
               l2_reg=0.001, lr=0.001):
    """Build CNN model with configurable architecture."""
    
    # Input layer
    inputs = keras.Input(shape=input_shape, name="input")
    x = inputs
    
    # Convolutional blocks
    for i, filters in enumerate(channels):
        for j in range(convs_per_block):
            x = layers.Conv2D(
                filters, 3, padding="same",
                kernel_regularizer=keras.regularizers.l2(l2_reg),
                name=f"conv_{i+1}_{j+1}"
            )(x)
            x = layers.BatchNormalization(name=f"bn_{i+1}_{j+1}")(x)
            
            if activation == "leakyrelu":
                x = layers.LeakyReLU(name=f"leaky_re_lu_{i+1}_{j+1}" if i==0 and j==0 else f"leaky_re_lu_{i+1}_{j+1}")(x)
            else:
                x = layers.Activation("relu", name=f"activation_{i+1}_{j+1}")(x)
        
        # Max pooling after each block (except last)
        if i < len(channels) - 1:
            x = layers.MaxPooling2D(2, name=f"pool_{i+1}")(x)
    
    # Global average pooling
    x = layers.GlobalAveragePooling2D(name="global_avg_pool")(x)
    
    # Dropout
    x = layers.Dropout(dropout_head, name="dropout_head")(x)
    
    # Output layer
    outputs = layers.Dense(num_classes, activation="softmax", name="output")(x)
    
    # Create model
    model = keras.Model(inputs, outputs, name="emotion_cnn")
    
    # Compile
    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=lr),
        loss="sparse_categorical_crossentropy",
        metrics=[METRIC_NAME]
    )
    
    return model

# Create model
input_shape = (*IMG_SIZE, 3 if MODEL_TYPE == "rgb" else 1)
model = build_cnn(
    input_shape=input_shape,
    num_classes=NUM_CLASSES,
    channels=CHANNELS,
    convs_per_block=CONVS_PER_BLOCK,
    dropout_head=DROPOUT_HEAD,
    activation="leakyrelu",
    l2_reg=L2_REG,
    lr=LEARNING_RATE
)

print(f"\nModel created: {MODEL_NAME}")
print(f"Input shape: {input_shape}")
print(f"Parameters: {model.count_params():,}")
model.summary()
# Out:
# Model created: complex_cnn_rgb_rgb_verification
# Input shape: (48, 48, 3)
# Parameters: 8,678,724
# Model: "emotion_cnn"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 48, 48, 3)]       0
#
#  conv_1_1 (Conv2D)           (None, 48, 48, 64)        1792
#
#  bn_1_1 (BatchNormalization  (None, 48, 48, 64)        256
#  )
#
#  leaky_re_lu_1_1 (LeakyReLU  (None, 48, 48, 64)        0
#  )
#
#  conv_1_2 (Conv2D)           (None, 48, 48, 64)        36928
#
#  bn_1_2 (BatchNormalization  (None, 48, 48, 64)        256
#  )
#
#  leaky_re_lu_1_2 (LeakyReLU  (None, 48, 48, 64)        0
#  )
#
#  pool_1 (MaxPooling2D)       (None, 24, 24, 64)        0
#
#  conv_2_1 (Conv2D)           (None, 24, 24, 128)       73856
#
#  bn_2_1 (BatchNormalization  (None, 24, 24, 128)       512
#  )
#
#  leaky_re_lu_2_1 (LeakyReLU  (None, 24, 24, 128)       0
#  )
#
#  conv_2_2 (Conv2D)           (None, 24, 24, 128)       147584
#
#  bn_2_2 (BatchNormalization  (None, 24, 24, 128)       512
#  )
#
#  leaky_re_lu_2_2 (LeakyReLU  (None, 24, 24, 128)       0
#  )
#
#  pool_2 (MaxPooling2D)       (None, 12, 12, 128)       0
#
#  conv_3_1 (Conv2D)           (None, 12, 12, 512)       590336
#
#  bn_3_1 (BatchNormalization  (None, 12, 12, 512)       2048
#  )
#
#  leaky_re_lu_3_1 (LeakyReLU  (None, 12, 12, 512)       0
#  )
#
#  conv_3_2 (Conv2D)           (None, 12, 12, 512)       2359808
#
#  bn_3_2 (BatchNormalization  (None, 12, 12, 512)       2048
#  )
#
#  leaky_re_lu_3_2 (LeakyReLU  (None, 12, 12, 512)       0
#  )
#
#  pool_3 (MaxPooling2D)       (None, 6, 6, 512)         0
#
#  conv_4_1 (Conv2D)           (None, 6, 6, 512)         2359808
#
#  bn_4_1 (BatchNormalization  (None, 6, 6, 512)         2048
#  )
#
#  leaky_re_lu_4_1 (LeakyReLU  (None, 6, 6, 512)         0
#  )
#
#  conv_4_2 (Conv2D)           (None, 6, 6, 512)         2359808
#
#  bn_4_2 (BatchNormalization  (None, 6, 6, 512)         2048
#  )
#
#  leaky_re_lu_4_2 (LeakyReLU  (None, 6, 6, 512)         0
#  )
#
#  pool_4 (MaxPooling2D)       (None, 3, 3, 512)         0
#
#  conv_5_1 (Conv2D)           (None, 3, 3, 128)         589952
#
#  bn_5_1 (BatchNormalization  (None, 3, 3, 128)         512
#  )
#
#  leaky_re_lu_5_1 (LeakyReLU  (None, 3, 3, 128)         0
#  )
#
#  conv_5_2 (Conv2D)           (None, 3, 3, 128)         147584
#
#  bn_5_2 (BatchNormalization  (None, 3, 3, 128)         512
#  )
#
#  leaky_re_lu_5_2 (LeakyReLU  (None, 3, 3, 128)         0
#  )
#
#  global_avg_pool (GlobalAve  (None, 128)               0
#  ragePooling2D)
#
#  dropout_head (Dropout)      (None, 128)               0
#
#  output (Dense)              (None, 4)                 516
#
# =================================================================
# Total params: 8678724 (33.11 MB)
# Trainable params: 8673348 (33.09 MB)
# Non-trainable params: 5376 (21.00 KB)
# _________________________________________________________________

# %%
# =============================================================================
# TRAINING
# =============================================================================

# Create callbacks
callbacks = [
    keras.callbacks.EarlyStopping(
        monitor="val_loss",
        patience=PATIENCE,
        restore_best_weights=True,
        verbose=1
    ),
    
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss",
        factor=0.5,
        patience=5,
        min_lr=1e-7,
        verbose=1
    ),
    
    keras.callbacks.ModelCheckpoint(
        filepath=str(MODELS_DIR / f"best_{MODEL_NAME}.keras"),
        monitor=VAL_METRIC_NAME,
        save_best_only=True,
        mode='max',
        verbose=1
    )
]

# Create run directory
run_dir = make_run_dir(RUN_DIR_NAME)

# Training configuration
print("=" * 70)
print(f"TRAINING CONFIGURATION - {MODEL_NAME}")
print("=" * 70)
print(f"Epochs: {EPOCHS}")
print(f"Batch size: {BATCH_SIZE}")
print(f"Learning rate: {LEARNING_RATE}")
print(f"Dropout: {DROPOUT_HEAD}")
print(f"L2 reg: {L2_REG}")
print(f"Class weights: {CLASS_WEIGHTS}")
print("=" * 70)

# Start training
start_time = time.time()
start_str = datetime.now().strftime("%Y-%m-%d %H:%M:%S")

print(f"\nTraining started at: {start_str}")

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=callbacks,
    class_weight=CLASS_WEIGHTS,
    verbose=1
)

end_time = time.time()
training_time = end_time - start_time

print(f"\nTraining completed in {training_time/60:.1f} minutes")
# Out:
# ======================================================================
# TRAINING CONFIGURATION - complex_cnn_rgb_rgb_verification
# ======================================================================
# Epochs: 50
# Batch size: 64
# Learning rate: 0.0001
# Dropout: 0.3
# L2 reg: 0.001
# Class weights: {0: 0.95, 1: 0.95, 2: 0.949, 3: 1.19}
# ======================================================================
#
# Training started at: 2025-10-12 20:40:58
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1760301663.131396   47842 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 237/237 [==============================] - ETA: 0s - loss: 3.3261 - sparse_categorical_accuracy: 0.5493
# Epoch 1: val_sparse_categorical_accuracy improved from -inf to 0.22986, saving model to ../../models/best_complex_cnn_rgb_rgb_verification.keras
# 237/237 [==============================] - 26s 69ms/step - loss: 3.3261 - sparse_categorical_accuracy: 0.5493 - val_loss: 3.9024 - val_sparse_categorical_accuracy: 0.2299 - lr: 1.0000e-04
# Epoch 2/50
# 236/237 [============================>.] - ETA: 0s - loss: 2.9571 - sparse_categorical_accuracy: 0.6611
# Epoch 2: val_sparse_categorical_accuracy improved from 0.22986 to 0.53265, saving model to ../../models/best_complex_cnn_rgb_rgb_verification.keras
# 237/237 [==============================] - 11s 47ms/step - loss: 2.9571 - sparse_categorical_accuracy: 0.6611 - val_loss: 3.1925 - val_sparse_categorical_accuracy: 0.5327 - lr: 1.0000e-04
# Epoch 3/50
# 236/237 [============================>.] - ETA: 0s - loss: 2.7051 - sparse_categorical_accuracy: 0.7075
# Epoch 3: val_sparse_categorical_accuracy improved from 0.53265 to 0.67450, saving model to ../../models/best_complex_cnn_rgb_rgb_verification.keras
# 237/237 [==============================] - 10s 41ms/step - loss: 2.7050 - sparse_categorical_accuracy: 0.7075 - val_loss: 2.7859 - val_sparse_categorical_accuracy: 0.6745 - lr: 1.0000e-04
# Epoch 4/50
# 235/237 [============================>.] - ETA: 0s - loss: 2.4843 - sparse_categorical_accuracy: 0.7426
# Epoch 4: val_sparse_categorical_accuracy improved from 0.67450 to 0.69058, saving model to ../../models/best_complex_cnn_rgb_rgb_verification.keras
# 237/237 [==============================] - 10s 40ms/step - loss: 2.4840 - sparse_categorical_accuracy: 0.7428 - val_loss: 2.5795 - val_sparse_categorical_accuracy: 0.6906 - lr: 1.0000e-04
# Epoch 5/50
# 235/237 [============================>.] - ETA: 0s - loss: 2.3037 - sparse_categorical_accuracy: 0.7714
# Epoch 5: val_sparse_categorical_accuracy did not improve from 0.69058
# 237/237 [==============================] - 8s 35ms/step - loss: 2.3035 - sparse_categorical_accuracy: 0.7714 - val_loss: 2.5432 - val_sparse_categorical_accuracy: 0.6739 - lr: 1.0000e-04
# Epoch 6/50
# 235/237 [============================>.] - ETA: 0s - loss: 2.1349 - sparse_categorical_accuracy: 0.7941
# Epoch 6: val_sparse_categorical_accuracy improved from 0.69058 to 0.71670, saving model to ../../models/best_complex_cnn_rgb_rgb_verification.keras
# 237/237 [==============================] - 9s 38ms/step - loss: 2.1348 - sparse_categorical_accuracy: 0.7942 - val_loss: 2.2993 - val_sparse_categorical_accuracy: 0.7167 - lr: 1.0000e-04
# Epoch 7/50
# 235/237 [============================>.] - ETA: 0s - loss: 1.9961 - sparse_categorical_accuracy: 0.8183
# Epoch 7: val_sparse_categorical_accuracy did not improve from 0.71670
# 237/237 [==============================] - 8s 33ms/step - loss: 1.9960 - sparse_categorical_accuracy: 0.8183 - val_loss: 2.3275 - val_sparse_categorical_accuracy: 0.6791 - lr: 1.0000e-04
# Epoch 8/50
# 235/237 [============================>.] - ETA: 0s - loss: 1.8548 - sparse_categorical_accuracy: 0.8467
# Epoch 8: val_sparse_categorical_accuracy did not improve from 0.71670
# 237/237 [==============================] - 8s 33ms/step - loss: 1.8551 - sparse_categorical_accuracy: 0.8466 - val_loss: 2.3959 - val_sparse_categorical_accuracy: 0.6532 - lr: 1.0000e-04
# Epoch 9/50
# 236/237 [============================>.] - ETA: 0s - loss: 1.7412 - sparse_categorical_accuracy: 0.8655
# Epoch 9: val_sparse_categorical_accuracy did not improve from 0.71670
# 237/237 [==============================] - 9s 35ms/step - loss: 1.7411 - sparse_categorical_accuracy: 0.8655 - val_loss: 2.5301 - val_sparse_categorical_accuracy: 0.6403 - lr: 1.0000e-04
# Epoch 10/50
# 235/237 [============================>.] - ETA: 0s - loss: 1.6415 - sparse_categorical_accuracy: 0.8876
# Epoch 10: val_sparse_categorical_accuracy did not improve from 0.71670
# 237/237 [==============================] - 9s 35ms/step - loss: 1.6413 - sparse_categorical_accuracy: 0.8876 - val_loss: 2.2960 - val_sparse_categorical_accuracy: 0.6854 - lr: 1.0000e-04
# Epoch 11/50
# 236/237 [============================>.] - ETA: 0s - loss: 1.5597 - sparse_categorical_accuracy: 0.8978
# Epoch 11: val_sparse_categorical_accuracy did not improve from 0.71670
# 237/237 [==============================] - 8s 35ms/step - loss: 1.5597 - sparse_categorical_accuracy: 0.8977 - val_loss: 2.3809 - val_sparse_categorical_accuracy: 0.6649 - lr: 1.0000e-04
# Epoch 12/50
# 236/237 [============================>.] - ETA: 0s - loss: 1.4822 - sparse_categorical_accuracy: 0.9120
# Epoch 12: val_sparse_categorical_accuracy did not improve from 0.71670
# 237/237 [==============================] - 8s 33ms/step - loss: 1.4822 - sparse_categorical_accuracy: 0.9120 - val_loss: 2.3058 - val_sparse_categorical_accuracy: 0.6645 - lr: 1.0000e-04
# Epoch 13/50
# 236/237 [============================>.] - ETA: 0s - loss: 1.3921 - sparse_categorical_accuracy: 0.9305
# Epoch 13: val_sparse_categorical_accuracy did not improve from 0.71670
# 237/237 [==============================] - 8s 34ms/step - loss: 1.3921 - sparse_categorical_accuracy: 0.9305 - val_loss: 2.8302 - val_sparse_categorical_accuracy: 0.5507 - lr: 1.0000e-04
# Epoch 14/50
# 236/237 [============================>.] - ETA: 0s - loss: 1.3124 - sparse_categorical_accuracy: 0.9464
# Epoch 14: val_sparse_categorical_accuracy did not improve from 0.71670
# 237/237 [==============================] - 8s 33ms/step - loss: 1.3125 - sparse_categorical_accuracy: 0.9463 - val_loss: 2.5532 - val_sparse_categorical_accuracy: 0.6681 - lr: 1.0000e-04
# Epoch 15/50
# 236/237 [============================>.] - ETA: 0s - loss: 1.2840 - sparse_categorical_accuracy: 0.9390
# Epoch 15: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 15: val_sparse_categorical_accuracy did not improve from 0.71670
# 237/237 [==============================] - 8s 34ms/step - loss: 1.2839 - sparse_categorical_accuracy: 0.9390 - val_loss: 2.4142 - val_sparse_categorical_accuracy: 0.6845 - lr: 1.0000e-04
# Epoch 16/50
# 236/237 [============================>.] - ETA: 0s - loss: 1.1750 - sparse_categorical_accuracy: 0.9733
# Epoch 16: val_sparse_categorical_accuracy did not improve from 0.71670
# 237/237 [==============================] - 8s 34ms/step - loss: 1.1750 - sparse_categorical_accuracy: 0.9733 - val_loss: 2.2766 - val_sparse_categorical_accuracy: 0.6950 - lr: 5.0000e-05
# Epoch 17/50
# 236/237 [============================>.] - ETA: 0s - loss: 1.1144 - sparse_categorical_accuracy: 0.9848
# Epoch 17: val_sparse_categorical_accuracy improved from 0.71670 to 0.73036, saving model to ../../models/best_complex_cnn_rgb_rgb_verification.keras
# 237/237 [==============================] - 9s 37ms/step - loss: 1.1144 - sparse_categorical_accuracy: 0.9848 - val_loss: 1.9789 - val_sparse_categorical_accuracy: 0.7304 - lr: 5.0000e-05
# Epoch 18/50
# 235/237 [============================>.] - ETA: 0s - loss: 1.0702 - sparse_categorical_accuracy: 0.9911
# Epoch 18: val_sparse_categorical_accuracy improved from 0.73036 to 0.73096, saving model to ../../models/best_complex_cnn_rgb_rgb_verification.keras
# 237/237 [==============================] - 9s 37ms/step - loss: 1.0701 - sparse_categorical_accuracy: 0.9911 - val_loss: 2.0812 - val_sparse_categorical_accuracy: 0.7310 - lr: 5.0000e-05
# Epoch 19/50
# 235/237 [============================>.] - ETA: 0s - loss: 1.0429 - sparse_categorical_accuracy: 0.9917
# Epoch 19: val_sparse_categorical_accuracy improved from 0.73096 to 0.73699, saving model to ../../models/best_complex_cnn_rgb_rgb_verification.keras
# 237/237 [==============================] - 9s 37ms/step - loss: 1.0428 - sparse_categorical_accuracy: 0.9917 - val_loss: 2.0504 - val_sparse_categorical_accuracy: 0.7370 - lr: 5.0000e-05
# Epoch 20/50
# 236/237 [============================>.] - ETA: 0s - loss: 1.0041 - sparse_categorical_accuracy: 0.9938
# Epoch 20: val_sparse_categorical_accuracy did not improve from 0.73699
# 237/237 [==============================] - 8s 33ms/step - loss: 1.0042 - sparse_categorical_accuracy: 0.9938 - val_loss: 2.3288 - val_sparse_categorical_accuracy: 0.6970 - lr: 5.0000e-05
# Epoch 21/50
# 237/237 [==============================] - ETA: 0s - loss: 1.0127 - sparse_categorical_accuracy: 0.9816
# Epoch 21: val_sparse_categorical_accuracy did not improve from 0.73699
# 237/237 [==============================] - 8s 32ms/step - loss: 1.0127 - sparse_categorical_accuracy: 0.9816 - val_loss: 2.0633 - val_sparse_categorical_accuracy: 0.7265 - lr: 5.0000e-05
# Epoch 22/50
# 236/237 [============================>.] - ETA: 0s - loss: 0.9708 - sparse_categorical_accuracy: 0.9882
# Epoch 22: val_sparse_categorical_accuracy improved from 0.73699 to 0.74402, saving model to ../../models/best_complex_cnn_rgb_rgb_verification.keras
# 237/237 [==============================] - 9s 36ms/step - loss: 0.9708 - sparse_categorical_accuracy: 0.9882 - val_loss: 1.9584 - val_sparse_categorical_accuracy: 0.7440 - lr: 5.0000e-05
# Epoch 23/50
# 235/237 [============================>.] - ETA: 0s - loss: 0.9306 - sparse_categorical_accuracy: 0.9930
# Epoch 23: val_sparse_categorical_accuracy did not improve from 0.74402
# 237/237 [==============================] - 8s 34ms/step - loss: 0.9306 - sparse_categorical_accuracy: 0.9930 - val_loss: 2.1548 - val_sparse_categorical_accuracy: 0.7014 - lr: 5.0000e-05
# Epoch 24/50
# 235/237 [============================>.] - ETA: 0s - loss: 0.9193 - sparse_categorical_accuracy: 0.9870
# Epoch 24: val_sparse_categorical_accuracy did not improve from 0.74402
# 237/237 [==============================] - 8s 33ms/step - loss: 0.9197 - sparse_categorical_accuracy: 0.9867 - val_loss: 2.3660 - val_sparse_categorical_accuracy: 0.6874 - lr: 5.0000e-05
# Epoch 25/50
# 235/237 [============================>.] - ETA: 0s - loss: 0.9061 - sparse_categorical_accuracy: 0.9860
# Epoch 25: val_sparse_categorical_accuracy did not improve from 0.74402
# 237/237 [==============================] - 8s 33ms/step - loss: 0.9061 - sparse_categorical_accuracy: 0.9860 - val_loss: 2.2313 - val_sparse_categorical_accuracy: 0.6854 - lr: 5.0000e-05
# Epoch 26/50
# 235/237 [============================>.] - ETA: 0s - loss: 0.8763 - sparse_categorical_accuracy: 0.9889
# Epoch 26: val_sparse_categorical_accuracy did not improve from 0.74402
# 237/237 [==============================] - 8s 33ms/step - loss: 0.8762 - sparse_categorical_accuracy: 0.9889 - val_loss: 2.6502 - val_sparse_categorical_accuracy: 0.6452 - lr: 5.0000e-05
# Epoch 27/50
# 235/237 [============================>.] - ETA: 0s - loss: 0.8513 - sparse_categorical_accuracy: 0.9896
# Epoch 27: val_sparse_categorical_accuracy did not improve from 0.74402
# 237/237 [==============================] - 8s 33ms/step - loss: 0.8512 - sparse_categorical_accuracy: 0.9897 - val_loss: 1.8351 - val_sparse_categorical_accuracy: 0.7430 - lr: 5.0000e-05
# Epoch 28/50
# 235/237 [============================>.] - ETA: 0s - loss: 0.8355 - sparse_categorical_accuracy: 0.9879
# Epoch 28: val_sparse_categorical_accuracy did not improve from 0.74402
# 237/237 [==============================] - 8s 34ms/step - loss: 0.8358 - sparse_categorical_accuracy: 0.9878 - val_loss: 2.6588 - val_sparse_categorical_accuracy: 0.6440 - lr: 5.0000e-05
# Epoch 29/50
# 235/237 [============================>.] - ETA: 0s - loss: 0.8675 - sparse_categorical_accuracy: 0.9731
# Epoch 29: val_sparse_categorical_accuracy did not improve from 0.74402
# 237/237 [==============================] - 8s 32ms/step - loss: 0.8673 - sparse_categorical_accuracy: 0.9731 - val_loss: 1.9123 - val_sparse_categorical_accuracy: 0.7217 - lr: 5.0000e-05
# Epoch 30/50
# 236/237 [============================>.] - ETA: 0s - loss: 0.8145 - sparse_categorical_accuracy: 0.9849
# Epoch 30: val_sparse_categorical_accuracy did not improve from 0.74402
# 237/237 [==============================] - 8s 33ms/step - loss: 0.8149 - sparse_categorical_accuracy: 0.9848 - val_loss: 2.1997 - val_sparse_categorical_accuracy: 0.7010 - lr: 5.0000e-05
# Epoch 31/50
# 235/237 [============================>.] - ETA: 0s - loss: 0.8194 - sparse_categorical_accuracy: 0.9793
# Epoch 31: val_sparse_categorical_accuracy did not improve from 0.74402
# 237/237 [==============================] - 8s 33ms/step - loss: 0.8195 - sparse_categorical_accuracy: 0.9793 - val_loss: 2.2345 - val_sparse_categorical_accuracy: 0.6789 - lr: 5.0000e-05
# Epoch 32/50
# 236/237 [============================>.] - ETA: 0s - loss: 0.8141 - sparse_categorical_accuracy: 0.9784
# Epoch 32: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
#
# Epoch 32: val_sparse_categorical_accuracy did not improve from 0.74402
# 237/237 [==============================] - 8s 33ms/step - loss: 0.8141 - sparse_categorical_accuracy: 0.9784 - val_loss: 2.9878 - val_sparse_categorical_accuracy: 0.6022 - lr: 5.0000e-05
# Epoch 33/50
# 236/237 [============================>.] - ETA: 0s - loss: 0.7616 - sparse_categorical_accuracy: 0.9936
# Epoch 33: val_sparse_categorical_accuracy did not improve from 0.74402
# 237/237 [==============================] - 8s 34ms/step - loss: 0.7618 - sparse_categorical_accuracy: 0.9935 - val_loss: 1.8348 - val_sparse_categorical_accuracy: 0.7394 - lr: 2.5000e-05
# Epoch 34/50
# 235/237 [============================>.] - ETA: 0s - loss: 0.7523 - sparse_categorical_accuracy: 0.9937
# Epoch 34: val_sparse_categorical_accuracy improved from 0.74402 to 0.75166, saving model to ../../models/best_complex_cnn_rgb_rgb_verification.keras
# 237/237 [==============================] - 9s 37ms/step - loss: 0.7523 - sparse_categorical_accuracy: 0.9936 - val_loss: 1.7160 - val_sparse_categorical_accuracy: 0.7517 - lr: 2.5000e-05
# Epoch 35/50
# 235/237 [============================>.] - ETA: 0s - loss: 0.7337 - sparse_categorical_accuracy: 0.9973
# Epoch 35: val_sparse_categorical_accuracy did not improve from 0.75166
# 237/237 [==============================] - 8s 35ms/step - loss: 0.7338 - sparse_categorical_accuracy: 0.9973 - val_loss: 1.7775 - val_sparse_categorical_accuracy: 0.7448 - lr: 2.5000e-05
# Epoch 36/50
# 236/237 [============================>.] - ETA: 0s - loss: 0.7196 - sparse_categorical_accuracy: 0.9987
# Epoch 36: val_sparse_categorical_accuracy did not improve from 0.75166
# 237/237 [==============================] - 8s 35ms/step - loss: 0.7208 - sparse_categorical_accuracy: 0.9987 - val_loss: 1.7592 - val_sparse_categorical_accuracy: 0.7462 - lr: 2.5000e-05
# Epoch 37/50
# 235/237 [============================>.] - ETA: 0s - loss: 0.7137 - sparse_categorical_accuracy: 0.9979
# Epoch 37: val_sparse_categorical_accuracy did not improve from 0.75166
# 237/237 [==============================] - 8s 34ms/step - loss: 0.7137 - sparse_categorical_accuracy: 0.9978 - val_loss: 1.8031 - val_sparse_categorical_accuracy: 0.7507 - lr: 2.5000e-05
# Epoch 38/50
# 236/237 [============================>.] - ETA: 0s - loss: 0.7088 - sparse_categorical_accuracy: 0.9966
# Epoch 38: val_sparse_categorical_accuracy did not improve from 0.75166
# 237/237 [==============================] - 9s 35ms/step - loss: 0.7088 - sparse_categorical_accuracy: 0.9966 - val_loss: 1.7488 - val_sparse_categorical_accuracy: 0.7452 - lr: 2.5000e-05
# Epoch 39/50
# 236/237 [============================>.] - ETA: 0s - loss: 0.6913 - sparse_categorical_accuracy: 0.9986
# Epoch 39: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
#
# Epoch 39: val_sparse_categorical_accuracy did not improve from 0.75166
# 237/237 [==============================] - 8s 34ms/step - loss: 0.6913 - sparse_categorical_accuracy: 0.9986 - val_loss: 1.7999 - val_sparse_categorical_accuracy: 0.7354 - lr: 2.5000e-05
# Epoch 40/50
# 235/237 [============================>.] - ETA: 0s - loss: 0.6820 - sparse_categorical_accuracy: 0.9985
# Epoch 40: val_sparse_categorical_accuracy did not improve from 0.75166
# 237/237 [==============================] - 9s 35ms/step - loss: 0.6821 - sparse_categorical_accuracy: 0.9985 - val_loss: 1.7194 - val_sparse_categorical_accuracy: 0.7486 - lr: 1.2500e-05
# Epoch 41/50
# 235/237 [============================>.] - ETA: 0s - loss: 0.6762 - sparse_categorical_accuracy: 0.9983
# Epoch 41: val_sparse_categorical_accuracy did not improve from 0.75166
# 237/237 [==============================] - 8s 33ms/step - loss: 0.6761 - sparse_categorical_accuracy: 0.9983 - val_loss: 1.7816 - val_sparse_categorical_accuracy: 0.7442 - lr: 1.2500e-05
# Epoch 42/50
# 236/237 [============================>.] - ETA: 0s - loss: 0.6668 - sparse_categorical_accuracy: 0.9992
# Epoch 42: val_sparse_categorical_accuracy did not improve from 0.75166
# 237/237 [==============================] - 8s 34ms/step - loss: 0.6668 - sparse_categorical_accuracy: 0.9992 - val_loss: 1.7467 - val_sparse_categorical_accuracy: 0.7509 - lr: 1.2500e-05
# Epoch 43/50
# 236/237 [============================>.] - ETA: 0s - loss: 0.6616 - sparse_categorical_accuracy: 0.9988
# Epoch 43: val_sparse_categorical_accuracy did not improve from 0.75166
# 237/237 [==============================] - 9s 36ms/step - loss: 0.6616 - sparse_categorical_accuracy: 0.9988 - val_loss: 1.7941 - val_sparse_categorical_accuracy: 0.7464 - lr: 1.2500e-05
# Epoch 44/50
# 235/237 [============================>.] - ETA: 0s - loss: 0.6525 - sparse_categorical_accuracy: 0.9993Restoring model weights from the end of the best epoch: 34.
#
# Epoch 44: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
#
# Epoch 44: val_sparse_categorical_accuracy did not improve from 0.75166
# 237/237 [==============================] - 8s 34ms/step - loss: 0.6525 - sparse_categorical_accuracy: 0.9993 - val_loss: 1.7976 - val_sparse_categorical_accuracy: 0.7492 - lr: 1.2500e-05
# Epoch 44: early stopping
#
# Training completed in 6.5 minutes

# %%
# =============================================================================
# EVALUATION
# =============================================================================

print("=" * 70)
print(f"EVALUATION - {MODEL_NAME}")
print("=" * 70)

# Get predictions
y_true = []
y_pred = []

for batch in test_ds:
    images, labels = batch
    predictions = model.predict(images, verbose=0)
    y_true.extend(labels.numpy())
    y_pred.extend(np.argmax(predictions, axis=1))

# Calculate metrics
test_accuracy = f1_score(y_true, y_pred, average='weighted')
test_macro_f1 = f1_score(y_true, y_pred, average='macro')
test_weighted_f1 = f1_score(y_true, y_pred, average='weighted')

# Display results
print(f"Test accuracy: {test_accuracy:.3f}")
print(f"Test macro F1: {test_macro_f1:.3f}")
print(f"Test weighted F1: {test_weighted_f1:.3f}")
print("=" * 70)

# Save results
results = {
    "experiment_name": EXPERIMENT_NAME,
    "experiment_description": EXPERIMENT_DESCRIPTION,
    "model_name": MODEL_NAME,
    "model_type": MODEL_TYPE,
    "architecture_type": ARCHITECTURE_TYPE,
    "channels": CHANNELS,
    "convs_per_block": CONVS_PER_BLOCK,
    "input_shape": list(input_shape),
    "dropout_head": DROPOUT_HEAD,
    "l2_reg": L2_REG,
    "learning_rate": LEARNING_RATE,
    "epochs": EPOCHS,
    "batch_size": BATCH_SIZE,
    "augment": AUGMENT,
    "training_time_minutes": training_time / 60,
    "test_accuracy": test_accuracy,
    "test_macro_f1": test_macro_f1,
    "test_weighted_f1": test_weighted_f1,
    "total_epochs_trained": len(history.history['loss']),
    "final_train_acc": history.history[METRIC_NAME][-1],
    "final_train_loss": history.history['loss'][-1],
    "final_val_acc": history.history[VAL_METRIC_NAME][-1],
    "final_val_loss": history.history['val_loss'][-1],
    "best_val_acc": max(history.history[VAL_METRIC_NAME]),
    "best_epoch": history.history[VAL_METRIC_NAME].index(max(history.history[VAL_METRIC_NAME])) + 1
}

# Save to run directory
save_metrics(results, run_dir / "experiment_results.json")
save_metrics(results, run_dir / "config.json")

print(f"\nResults saved to: {run_dir}")
print(f"Experiment completed: {EXPERIMENT_NAME}")
# Out:
# ======================================================================
# EVALUATION - complex_cnn_rgb_rgb_verification
# ======================================================================
# Test accuracy: 0.800
# Test macro F1: 0.800
# Test weighted F1: 0.800
# ======================================================================
#
# Results saved to: ../../runs/20251012-204058_rgb_rgb_verification
# Experiment completed: rgb_verification

# %%
# =============================================================================
# VISUALIZATION
# =============================================================================

# Plot training history
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

# Accuracy plot
axes[0].plot(history.history[METRIC_NAME], label='train', linewidth=2)
axes[0].plot(history.history[VAL_METRIC_NAME], label='validation', linewidth=2)
axes[0].set_title(f'Accuracy - {MODEL_NAME}')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Accuracy')
axes[0].legend()
axes[0].grid(True, alpha=0.3)

# Loss plot
axes[1].plot(history.history['loss'], label='train', linewidth=2)
axes[1].plot(history.history['val_loss'], label='validation', linewidth=2)
axes[1].set_title(f'Loss - {MODEL_NAME}')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Loss')
axes[1].legend()
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig(run_dir / "training_history.png", dpi=150, bbox_inches="tight")
plt.show()

# Confusion matrix
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.colorbar()

tick_marks = np.arange(len(CLASS_ORDER))
plt.xticks(tick_marks, CLASS_ORDER, rotation=45)
plt.yticks(tick_marks, CLASS_ORDER)

# Add text annotations
thresh = cm.max() / 2.
for i, j in np.ndindex(cm.shape):
    plt.text(j, i, cm[i, j], horizontalalignment="center",
             color="white" if cm[i, j] > thresh else "black", fontsize=10)

plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title(f'Confusion Matrix - {MODEL_NAME}')
plt.tight_layout()
plt.savefig(run_dir / "confusion_matrix.png", dpi=150, bbox_inches="tight")
plt.show()

print(f"Visualizations saved to: {run_dir}")
# Out:
# Visualizations saved to: ../../runs/20251012-204058_rgb_rgb_verification
